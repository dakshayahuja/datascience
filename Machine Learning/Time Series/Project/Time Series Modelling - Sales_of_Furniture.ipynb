# %% [markdown]
# # Forecasting the Sales of a Furniture store
# We are using Superstore sales data for furniture sales between 2014 to 2017 and apply a simple model to forecast for 2018

# %% [markdown]
# ## Content
#
# 1. **[Import packages](#import_packages)**
# 2. **[Load data](#load_data)**
# 3. **[Data preparation](#data_preparation)**
#     - 3.1 - [Dimensions of Dataset](#data_dimension)
#     - 3.2 - [Statistical Summary](#Stat_sum)
#     - 3.3 - [Checking Data Type and Missing Values](#check_data_type)
#     - 3.4 - [Indexing with Date](#Indexing_with_Date)
# 4. **[Time Series Analysis](#Time_Series_Analysis)**
#     - 4.1 - [Visualizing data](#Visualizing_data)
#     - 4.2 - [Sampling](#Sampling)
#     - 4.3 - [Checking Stationarity](#Checking_Stationarity)
#     - 4.4 - [Decomposing](#Decomposing)
# 5. **[Time Series Forcasting using ARIMA](#Time_Series_Forcasting_using_ARIMA)**
#     - 5.1 - [Parameter Selection](#Parameter_Selection)
#     - 5.2 - [Fitting the ARIMA model](#Fitting_the_ARIMA)
#     - 5.3 - [Validating Forecasts](#Validating_Forecasts)
#     - 5.4 - [Calculating MSE and RMSE](#Calculating_MSE_and_RMSE)
#     - 5.5 - [Visualizing the Forecast](#Visualizing_the_Forecast)
# 6. **[Conclusion](#Conclusion)**

# %% [markdown]
# <a id='import_packages'></a>
# # 1. Import Packages

# %%
import itertools
import warnings
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
sns.set()
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id='load_data'></a>
# # 2. Load Data

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="key.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b>Load the data using read_csv() function from pandas<br>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
furniture = pd.read_csv("Super_Store.csv",sep=",", encoding='cp1252')
furniture.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 4      11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 2   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 3  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
# 4  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
#    Region       Product ID   Category Sub-Category  \
# 0   South  FUR-BO-10001798  Furniture    Bookcases
# 1   South  FUR-CH-10000454  Furniture       Chairs
# 2   South  FUR-TA-10000577  Furniture       Tables
# 3    West  FUR-FU-10001487  Furniture  Furnishings
# 4    West  FUR-TA-10001539  Furniture       Tables
#
#                                         Product Name      Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase   261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400         3
# 2      Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 3  Eldon Expressions Wood and Plastic Desk Access...    48.8600         7
# 4           Chromcraft Rectangular Conference Tables  1706.1840         9
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.45 -383.0310
# 3      0.00   14.1694
# 4      0.20   85.3092
#
# [5 rows x 21 columns]

# %% [markdown]
# <a id='data_preparation'></a>
# # 3. Data Preparation

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="key.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b>The process of data preparation entails cleansing, structuring and integrating data to make it ready for analysis. <br><br>
#                         Here we will analyze and prepare data to perform regression techniques:<br>
#                         1. Check dimensions and data types of the dataframe <br>
#                         2. Study summary statistics<br>
#                         3. Converting date into standard format<br>
#                         4. Check for missing values<br>
#                         5. Study correlation<br>
#                                        </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id='data_dimension'></a>
# # 3.1 Dimensions of Dataset
# We get a quick idea of how many instances (rows) and how many attributes (columns) the data contains with the shape property.

# %%
# Checking structure of the data
furniture.shape
# Out:
# (2121, 21)

# %% [markdown]
# <a id='Stat_sum'></a>
# # 3.2 Statistical Summary
# Here we take a look at the summary of each attribute.
#
# This includes the count, mean, the min and max values as well as percentiles.

# %%
furniture.describe()
# Out:
#             Row ID   Postal Code        Sales     Quantity     Discount  \
# count  2121.000000   2121.000000  2121.000000  2121.000000  2121.000000
# mean   5041.643564  55726.556341   349.834887     3.785007     0.173923
# std    2885.740258  32261.888225   503.179145     2.251620     0.181547
# min       1.000000   1040.000000     1.892000     1.000000     0.000000
# 25%    2568.000000  22801.000000    47.040000     2.000000     0.000000
# 50%    5145.000000  60505.000000   182.220000     3.000000     0.200000
# 75%    7534.000000  90032.000000   435.168000     5.000000     0.300000
# max    9991.000000  99301.000000  4416.174000    14.000000     0.700000
#
#             Profit
# count  2121.000000
# mean      8.699327
# std     136.049246
# min   -1862.312400
# 25%     -12.849000
# 50%       7.774800
# 75%      33.726600
# max    1013.127000

# %% [markdown]
# <a id='check_data_type'></a>
# ## 3.3 Checking for Missing Values

# %%
# summary of the data 
furniture.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2121 entries, 0 to 2120
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         2121 non-null   int64
#  1   Order ID       2121 non-null   object
#  2   Order Date     2121 non-null   object
#  3   Ship Date      2121 non-null   object
#  4   Ship Mode      2121 non-null   object
#  5   Customer ID    2121 non-null   object
#  6   Customer Name  2121 non-null   object
#  7   Segment        2121 non-null   object
#  8   Country        2121 non-null   object
#  9   City           2121 non-null   object
#  10  State          2121 non-null   object
#  11  Postal Code    2121 non-null   int64
#  12  Region         2121 non-null   object
#  13  Product ID     2121 non-null   object
#  14  Category       2121 non-null   object
#  15  Sub-Category   2121 non-null   object
#  16  Product Name   2121 non-null   object
#  17  Sales          2121 non-null   float64
#  18  Quantity       2121 non-null   int64
#  19  Discount       2121 non-null   float64
#  20  Profit         2121 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 348.1+ KB

# %% [markdown]
# Checking the stock time stamp

# %%
furniture['Order Date'].min(), furniture['Order Date'].max()
# Out:
# ('1/1/2017', '9/9/2017')

# %% [markdown]
# We remove the columns that we do not need as well as check missing values

# %%
cols = ['Row ID', 'Order ID', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Quantity', 'Discount', 'Profit']
furniture.drop(cols, axis=1, inplace=True)
furniture = furniture.sort_values('Order Date')

# %% [markdown]
# Checking for null values

# %%
furniture.isnull().sum()
# Out:
# Order Date    0
# Sales         0
# dtype: int64

# %% [markdown]
# <table align='left'>
#     <tr>
#         <td width='8%'>
#             <img src='note.png'>
#         </td>
#         <td>
#             <div align='left', style='font-size:120%'>
#                     <b>There are no missing values<br>
#                     </br></b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id='Indexing_with_Date'></a>
# ## 3.5 Indexing with Date

# %% [markdown]
# Aggregate price by date

# %%
furniture = furniture.groupby('Order Date')['Sales'].sum().reset_index()

# %%
furniture['Order Date'] = pd.to_datetime(furniture['Order Date'])
furniture.set_index('Order Date', inplace=True)
furniture.index
# Out:
# DatetimeIndex(['2017-01-01', '2014-01-10', '2015-01-10', '2016-01-10',
#                '2014-01-11', '2016-01-11', '2017-01-12', '2014-01-13',
#                '2015-01-13', '2017-01-13',
#                ...
#                '2014-09-07', '2015-09-07', '2017-09-07', '2014-09-08',
#                '2015-09-08', '2016-09-08', '2017-09-08', '2014-09-09',
#                '2016-09-09', '2017-09-09'],
#               dtype='datetime64[ns]', name='Order Date', length=889, freq=None)

# %%
furniture.head()
# Out:
#                Sales
# Order Date
# 2017-01-01   975.490
# 2014-01-10    51.940
# 2015-01-10  1018.104
# 2016-01-10   104.770
# 2014-01-11     9.940

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
# <b>Resampling the datetime data. Here we use the start of each month as the timestamp and take the average daily sales value for a particular month since working with the current datetime data becomes tricky</b>     </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id='Time_Series_Analysis'></a>
# # 4. Time Series Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="key.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b> Now we analysis Time series data to do so we need to perform following steps <br><br>
#                         1. Visualizing Data <br>
#                         2. Sampling<br>
#                         3. Checking Stationarity <br>
#                         4. Decomposing<br>
#                       </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id='Visualizing_data'></a>
# ## 4.1 Visualizing data

# %%
furniture.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# <a id='Sampling'></a>
# ## 4.2 Sampling

# %%
y = furniture['Sales'].resample('MS').mean()

# %%
y
# Out:
# Order Date
# 2014-01-01     480.194231
# 2014-02-01     367.931600
# 2014-03-01     857.291529
# 2014-04-01     567.488357
# 2014-05-01     432.049188
# 2014-06-01     695.059242
# 2014-07-01     601.169500
# 2014-08-01     457.521656
# 2014-09-01     992.353367
# 2014-10-01     769.015437
# 2014-11-01     980.221486
# 2014-12-01    1532.298325
# 2015-01-01     978.328467
# 2015-02-01     522.395667
# 2015-03-01     781.236437
# 2015-04-01     805.822962
# 2015-05-01     624.996700
# 2015-06-01     428.565500
# 2015-07-01     719.706316
# 2015-08-01     602.412012
# 2015-09-01    1382.790684
# 2015-10-01     632.980184
# 2015-11-01    1286.701354
# 2015-12-01    1049.355418
# 2016-01-01     508.182867
# 2016-02-01     356.868273
# 2016-03-01     609.575810
# 2016-04-01     695.373158
# 2016-05-01     687.265227
# 2016-06-01     816.910750
# 2016-07-01     768.736412
# 2016-08-01     734.307782
# 2016-09-01    1135.953371
# 2016-10-01     624.872474
# 2016-11-01    1271.345152
# 2016-12-01    1410.719808
# 2017-01-01     397.602133
# 2017-02-01     528.179800
# 2017-03-01     544.672240
# 2017-04-01     453.297905
# 2017-05-01     678.302328
# 2017-06-01     826.460291
# 2017-07-01     562.524857
# 2017-08-01     857.881889
# 2017-09-01    1209.508583
# 2017-10-01     875.362728
# 2017-11-01    1277.817759
# 2017-12-01    1256.298672
# Freq: MS, Name: Sales, dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(y)

plt.plot(y, label = 'Original')
plt.legend(loc = 'best')

trend = decomposition.trend
plt.show()
plt.plot(trend, label = 'Trend')
plt.legend(loc = 'best')

seasonal = decomposition.seasonal
plt.show()
plt.plot(seasonal, label = 'Seasonal')
plt.legend(loc = 'best')

residual = decomposition.resid
plt.show()
plt.plot(residual, label = 'Residual')
plt.legend(loc='best')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b>The plot clearly indicates that the time series has seasonality pattern.The sales are always low at the beginning of the year and high at the end of the year. There is always an upward trend within any single year with a couple of low months in the mid of the year</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id='Checking_Stationarity'></a>
# ## 4.3 Checking Stationarity

# %% [markdown]
# Our first step in time-series analysis should be to check whether there is any evidence of a trend or seasonal effects and, if there is, remove them. Augmented Dickey-Fuller(ADF) statistics is one of the more widely used statistical test to check whether your time series is stationary or non-stationary. It uses an autoregressive model and optimizes an information criterion across multiple different lag values.

# %% [markdown]
# **Null Hypothesis: The series has a unit root (value of a =1)(not stationary)**
#
# **Alternate Hypothesis: The series has no unit root (stationary)**

# %%
from statsmodels.tsa.stattools import adfuller

# %%
from pandas import Series
from statsmodels.tsa.stattools import adfuller
#series = Series.from_csv('daily-total-female-births.csv', header=0)
result = adfuller(y)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.191070
# p-value: 0.000009
# Critical Values:
# 	1%: -3.621
# 	5%: -2.944
# 	10%: -2.610

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b>We can see that our statistic value of -4.756843 is less than the value of -3.578 at 1%. This suggests that we can reject the null hypothesis with a significance level of less than 1% (i.e. a low probability that the result is a statistical fluke). Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.
#
# The p-value is 0.000009, which is way below the threshold (0.05). Hence the null-hypothesis is rejected. It suggests the time series does not have a unit root, meaning it is stationary.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id='Decomposing'></a>
# ## 4.4 Decomposing
#
# Decomposing the time series into three distinct components: trend, seasonality, and noise.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(y)

plt.plot(y, label = 'Original')
plt.legend(loc = 'best')

trend = decomposition.trend
plt.show()
plt.plot(trend, label = 'Trend')
plt.legend(loc = 'best')

seasonal = decomposition.seasonal
plt.show()
plt.plot(seasonal, label = 'Seasonal')
plt.legend(loc = 'best')

residual = decomposition.resid
plt.show()
plt.plot(residual, label = 'Residual')
plt.legend(loc='best')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b>By visualizing the decomposed components of the original time series we can say that the price of stock is unstable, along with its obvious seasonality.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id='Time_Series_Forcasting_using_ARIMA'></a>
# # 5. Time Series Forcasting using ARIMA

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="key.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b> We will use ARIMA for forecasting our time series. ARIMA is also denoted as ARIMA(p,d,q) where p,d,q accounts for seasonality, trend and noise in the time series data</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %% [markdown]
# <a id='Parameter_Selection'></a>
# ## 5.1 Parameter Selection

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="key.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b>We use “grid search” to find the optimal set of parameters that yields the best performance for our model</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from pylab import rcParams
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y, order=param,
seasonal_order=param_seasonal,
enforce_stationarity=False, 
enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.99048D+00    |proj g|=  1.66962D-05
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:769.0817523335078
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      3      1     0     0   2.415D-07   7.990D+00
#   F =   7.9904349201407063
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.91500D+01    |proj g|=  1.52192D-03
#   ys=-4.711E+01  -gs= 6.991E-01 BFGS update SKIPPED
#   ys=-3.104E+01  -gs= 7.128E-01 BFGS update SKIPPED
#   ys=-3.247E+01  -gs= 7.133E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5     86      3     3     0   2.904D+04   1.710D+01
#   F =   17.095310121731316
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1645.1497716862063
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.96130D+00    |proj g|=  7.02705D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      4      6      1     0     0   3.189D-07   4.955D+00
#   F =   4.9553855530417819
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:477.7170130920111
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.17740D+00    |proj g|=  1.58606D-01
#
# At iterate    5    f=  3.15483D+00    |proj g|=  4.29179D-03
#
# At iterate   10    f=  3.14156D+00    |proj g|=  1.12506D-01
#
# At iterate   15    f=  3.10698D+00    |proj g|=  6.55640D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     16     19      1     0     0   1.383D-05   3.107D+00
#   F =   3.1069821872850709
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:302.2702899793668
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.13783D+00    |proj g|=  5.05999D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     11      1     0     0   5.053D-05   5.138D+00
#   F =   5.1378275348107687
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:497.2314433418338
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.59169D+01    |proj g|=  4.99748D-03
#   ys=-2.855E+01  -gs= 7.114E-01 BFGS update SKIPPED
#   ys=-2.056E+01  -gs= 7.047E-01 BFGS update SKIPPED
#
# At iterate    5    f=  1.17648D+01    |proj g|=  2.08629D+05
#   ys=-4.172E+00  -gs= 6.175E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6     99      2     3     0   2.086D+05   1.176D+01
#   F =   11.764759135025750
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1135.416876962472
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27088D+00    |proj g|=  6.03837D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   6.038D-06   3.271D+00
#   F =   3.2708824990795224
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:318.00471991163414
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.17740D+00    |proj g|=  1.58606D-01
#
# At iterate    5    f=  3.15658D+00    |proj g|=  3.15535D-02
#
# At iterate   10    f=  3.15479D+00    |proj g|=  1.07910D-03
#
# At iterate   15    f=  3.12010D+00    |proj g|=  1.47086D-01
#
# At iterate   20    f=  3.10676D+00    |proj g|=  3.81941D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     21     31      1     0     0   2.891D-06   3.107D+00
#   F =   3.1067586253151216
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:304.2488280302517
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:720.925227075811
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.62082D+00    |proj g|=  2.76207D-01
#
# At iterate    5    f=  7.57452D+00    |proj g|=  1.26846D-03
#
# At iterate   10    f=  7.57422D+00    |proj g|=  2.93923D-02
#
# At iterate   15    f=  7.55111D+00    |proj g|=  2.39326D-01
#
# At iterate   20    f=  7.46798D+00    |proj g|=  2.90499D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     23     27      1     0     0   4.956D-08   7.468D+00
#   F =   7.4679711153730315
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.87325D+01    |proj g|=  4.50773D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#   ys=-4.336E+05  -gs= 2.286E-02 BFGS update SKIPPED
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:2725.0629060100364
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:466.5607429809162
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      3     69      3     1     0   1.168D+03   2.832D+01
#   F =   28.323571937604545
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.81850D+00    |proj g|=  1.63640D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   5.549D-05   4.818D+00
#   F =   4.8183410727178773
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.03608D+00    |proj g|=  1.53380D-01
#
# At iterate    5    f=  3.01401D+00    |proj g|=  3.58462D-03
#
# At iterate   10    f=  3.00248D+00    |proj g|=  9.13790D-02
#
# At iterate   15    f=  2.97527D+00    |proj g|=  7.09121D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     17     21      1     0     0   3.840D-07   2.975D+00
#   F =   2.9752722809096697
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:291.6261389673283
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.77847D+00    |proj g|=  3.74770D-02
#
# At iterate    5    f=  5.77414D+00    |proj g|=  8.20004D-04
#
# At iterate   10    f=  5.77045D+00    |proj g|=  3.10555D-02
#
# At iterate   15    f=  5.42367D+00    |proj g|=  2.22856D+00
#
# At iterate   20    f=  5.23797D+00    |proj g|=  5.22730D-01
#
# At iterate   25    f=  5.18502D+00    |proj g|=  1.92827D-01
#
# At iterate   30    f=  5.16011D+00    |proj g|=  5.54275D-02
#
# At iterate   35    f=  5.14999D+00    |proj g|=  2.85339D-03
#
# At iterate   40    f=  5.14596D+00    |proj g|=  3.04850D-02
#
# At iterate   45    f=  5.14362D+00    |proj g|=  2.09103D-02
#
# At iterate   50    f=  5.14178D+00    |proj g|=  2.11336D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     50     74      1     0     0   2.113D-03   5.142D+00
#   F =   5.1417825360352554
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:499.6111234593845
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64045D+01    |proj g|=  3.60056D-03
#   ys=-7.764E-08  -gs= 4.902E-07 BFGS update SKIPPED
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate    5    f=  2.56131D+01    |proj g|=  8.30888D+04
#   ys=-2.068E+05  -gs= 2.145E+00 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      6     79      3     2     0   8.309D+04   2.561D+01
#   F =   25.613138847273436
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:2466.86132933825
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.30136D+00    |proj g|=  8.81709D-03
#
# At iterate    5    f=  3.30121D+00    |proj g|=  1.24497D-03
#
# At iterate   10    f=  3.29918D+00    |proj g|=  3.27117D-02
#
# At iterate   15    f=  3.27151D+00    |proj g|=  2.08396D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     19     22      1     0     0   1.068D-06   3.271D+00
#   F =   3.2707134134863192
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:319.9884876946866
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.03608D+00    |proj g|=  1.53380D-01
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  3.01570D+00    |proj g|=  2.21140D-02
#
# At iterate   10    f=  3.01390D+00    |proj g|=  1.40286D-03
#
# At iterate   15    f=  3.01088D+00    |proj g|=  2.00598D-02
#
# At iterate   20    f=  2.96843D+00    |proj g|=  3.42249D-02
#
# At iterate   25    f=  2.95716D+00    |proj g|=  2.19675D-03
#
# At iterate   30    f=  2.95701D+00    |proj g|=  1.65136D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33     45      1     0     0   4.838D-06   2.957D+00
#   F =   2.9570058088450755
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:291.87255764912726
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.04097D+00    |proj g|=  1.08020D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      3      1     0     0   4.372D-06   7.041D+00
#   F =   7.0405704879317748
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:677.8947668414504
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.68582D+01    |proj g|=  2.80022D-03
#   ys=-2.494E+01  -gs= 6.893E-01 BFGS update SKIPPED
#   ys=-1.330E+02  -gs= 7.046E-01 BFGS update SKIPPED
#   ys=-2.735E+01  -gs= 7.013E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5     96      3     3     0   9.609D+04   1.464D+01
#   F =   14.639367862462320
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1409.3793147963827
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06688D+00    |proj g|=  9.86171D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      4      6      1     0     0   4.549D-06   5.048D+00
#   F =   5.0483110075006836
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:486.6378567200656
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.18743D+00    |proj g|=  1.32769D-01
#
# At iterate    5    f=  3.16516D+00    |proj g|=  2.09181D-03
#
# At iterate   10    f=  3.16263D+00    |proj g|=  3.87590D-02
#
# At iterate   15    f=  3.13511D+00    |proj g|=  4.53867D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     18     20      1     0     0   3.611D-07   3.135D+00
#   F =   3.1350741960082917
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:304.967122816796
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.14364D+00    |proj g|=  6.38920D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   6.389D-06   5.144D+00
#   F =   5.1436350656295913
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:497.7889663004408
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.61871D+01    |proj g|=  4.20820D-03
#   ys=-1.595E+02  -gs= 7.002E-01 BFGS update SKIPPED
#   ys=-4.359E+02  -gs= 7.072E-01 BFGS update SKIPPED
#   ys=-2.034E+02  -gs= 7.048E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4     54      4     3     0   1.722D+05   1.275D+01
#   F =   12.752110867950160
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1230.2026433232154
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.28929D+00    |proj g|=  4.82157D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   4.822D-06   3.289D+00
#   F =   3.2892854876137618
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:319.7714068109211
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.18743D+00    |proj g|=  1.32769D-01
#
# At iterate    5    f=  3.16631D+00    |proj g|=  3.88243D-02
#
# At iterate   10    f=  3.16499D+00    |proj g|=  1.49204D-03
#
# At iterate   15    f=  3.16428D+00    |proj g|=  2.53544D-02
#
# At iterate   20    f=  3.14603D+00    |proj g|=  6.53180D-02
#
# At iterate   25    f=  3.13510D+00    |proj g|=  5.58627D-03
#
# At iterate   30    f=  3.13449D+00    |proj g|=  1.09277D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     30     37      1     0     0   1.093D-06   3.134D+00
#   F =   3.1344929168243829
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:306.91132001514075
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.74578D+00    |proj g|=  8.96878D-02
#
# At iterate    5    f=  6.73017D+00    |proj g|=  3.27081D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      9     23      1     0     0   1.285D-05   6.728D+00
#   F =   6.7281835175180191
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:649.9056176817298
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.62718D+01    |proj g|=  7.20152D-03
#   ys=-5.143E-09  -gs= 1.130E-08 BFGS update SKIPPED
#   ys=-4.017E+01  -gs= 1.693E-01 BFGS update SKIPPED
#
# At iterate    5    f=  2.62528D+01    |proj g|=  2.53019D+02
#   ys=-1.293E+05  -gs= 2.075E+02 BFGS update SKIPPED
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      8    119      5     3     0   4.899D+05   2.145D+01
#   F =   21.449770521962574
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:2065.177970108407
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.76190D+00    |proj g|=  1.01285D-01
#
# At iterate    5    f=  4.74718D+00    |proj g|=  5.28400D-04
#
# At iterate   10    f=  4.74705D+00    |proj g|=  1.11249D-02
#
# At iterate   15    f=  4.73828D+00    |proj g|=  3.49613D-03
#
# At iterate   20    f=  4.73823D+00    |proj g|=  9.06830D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     20     22      1     0     0   9.068D-08   4.738D+00
#   F =   4.7382349463361928
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:458.87055484827454
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.97823D+00    |proj g|=  1.50080D-01
#
# At iterate    5    f=  2.92871D+00    |proj g|=  5.66975D-03
#
# At iterate   10    f=  2.92864D+00    |proj g|=  5.96714D-03
#
# At iterate   15    f=  2.92143D+00    |proj g|=  7.46461D-02
#
# At iterate   20    f=  2.87919D+00    |proj g|=  1.99190D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   25    f=  2.85662D+00    |proj g|=  4.00636D-02
#
# At iterate   30    f=  2.84985D+00    |proj g|=  3.99425D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     33     43      1     0     0   9.930D-06   2.850D+00
#   F =   2.8497981598252546
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:279.58062334322443
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.10670D+00    |proj g|=  3.57336D-02
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:486.1832977442712
#
# At iterate    5    f=  5.10219D+00    |proj g|=  1.15500D-03
#
# At iterate   10    f=  5.10002D+00    |proj g|=  2.93445D-02
#
# At iterate   15    f=  5.02195D+00    |proj g|=  1.34082D-01
#
# At iterate   20    f=  5.00192D+00    |proj g|=  4.23535D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     23     27      1     0     0   1.709D-06   5.002D+00
#   F =   5.0019093515028255
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.58912D+01    |proj g|=  6.97397D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      3     58      2     0     0   8.802D-01   2.588D+01
#   F =   25.877687597319966
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:2492.258009342717
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.23022D+00    |proj g|=  3.65785D-02
#
# At iterate    5    f=  3.22401D+00    |proj g|=  7.08917D-02
#
# At iterate   10    f=  3.21896D+00    |proj g|=  1.01148D-03
#
# At iterate   15    f=  3.21872D+00    |proj g|=  3.85927D-02
#
# At iterate   20    f=  3.17691D+00    |proj g|=  3.94985D-02
#
# At iterate   25    f=  3.17456D+00    |proj g|=  7.46183D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     28     43      1     0     0   4.829D-07   3.175D+00
#   F =   3.1745566337680167
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:310.7574368417296
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.97823D+00    |proj g|=  1.76039D-01
#
# At iterate    5    f=  2.93137D+00    |proj g|=  4.51405D-02
#
# At iterate   10    f=  2.92843D+00    |proj g|=  1.02500D-03
#
# At iterate   15    f=  2.92822D+00    |proj g|=  2.90989D-02
#
# At iterate   20    f=  2.89347D+00    |proj g|=  2.64524D-01
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# At iterate   25    f=  2.85822D+00    |proj g|=  2.18985D-01
#
# At iterate   30    f=  2.84956D+00    |proj g|=  8.30574D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33     45      1     0     0   6.301D-06   2.850D+00
#   F =   2.8495589806887991
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:281.5576621461247
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.16838D+00    |proj g|=  2.51956D-05
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:692.1645522067713
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     14      1     0     0   2.519D-05   7.168D+00
#   F =   7.1683807521538681
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.89680D+01    |proj g|=  1.92146D-03
#   ys=-3.112E+02  -gs= 7.278E-01 BFGS update SKIPPED
#
# At iterate    5    f=  1.62879D+01    |proj g|=  3.74916D+05
#   ys=-3.420E+03  -gs= 7.288E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7     89      2     2     0   8.647D+04   1.522D+01
#   F =   15.224528132052606
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1467.5547006770503
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.95274D+00    |proj g|=  4.17506D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   4.175D-06   4.953D+00
#   F =   4.9527418206793081
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:479.46321478521355
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.16805D+00    |proj g|=  1.64266D-01
#
# At iterate    5    f=  3.14466D+00    |proj g|=  1.77769D-03
#
# At iterate   10    f=  3.14134D+00    |proj g|=  3.70899D-02
#
# At iterate   15    f=  3.10841D+00    |proj g|=  4.52845D-02
#
# At iterate   20    f=  3.10633D+00    |proj g|=  1.63018D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     21     24      1     0     0   1.292D-06   3.106D+00
#   F =   3.1063309116259998
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:304.207767516096
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.19919D+00    |proj g|=  2.41292D-01
#
# At iterate    5    f=  5.09833D+00    |proj g|=  1.23092D-02
#
# At iterate   10    f=  5.09817D+00    |proj g|=  1.03693D-02
#
# At iterate   15    f=  5.07999D+00    |proj g|=  1.97990D-01
#
# At iterate   20    f=  4.94876D+00    |proj g|=  1.37180D-01
#
# At iterate   25    f=  4.94715D+00    |proj g|=  1.23775D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     26     30      1     0     0   5.000D-07   4.947D+00
#   F =   4.9471451749324986
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:480.92593679351984
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.65768D+01    |proj g|=  1.92501D-03
#
# At iterate    5    f=  2.65559D+01    |proj g|=  1.28809D-02
#   ys=-3.200E+01  -gs= 4.496E-01 BFGS update SKIPPED
#   ys=-4.241E+01  -gs= 7.183E-01 BFGS update SKIPPED
#   ys=-2.714E+01  -gs= 7.106E-01 BFGS update SKIPPED
#
# At iterate   10    f=  1.53719D+01    |proj g|=  8.99677D+03
#   ys=-2.685E+01  -gs= 7.103E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     11     95      2     4     0   8.997D+03   1.537D+01
#   F =   15.371908764758929
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1483.7032414168573
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.14966D+00    |proj g|=  6.73283D-02
#
# At iterate    5    f=  3.14546D+00    |proj g|=  3.59066D-03
#
# At iterate   10    f=  3.13253D+00    |proj g|=  7.92847D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   15    f=  3.10903D+00    |proj g|=  5.29964D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18     22      1     0     0   1.329D-06   3.109D+00
#   F =   3.1090257032131241
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:304.4664675084599
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.16805D+00    |proj g|=  1.64266D-01
#
# At iterate    5    f=  3.14669D+00    |proj g|=  2.12240D-02
#
# At iterate   10    f=  3.14460D+00    |proj g|=  2.49106D-03
#
# At iterate   15    f=  3.14450D+00    |proj g|=  4.78054D-03
#
# At iterate   20    f=  3.13450D+00    |proj g|=  6.55616D-02
#
# At iterate   25    f=  3.10013D+00    |proj g|=  7.09170D-02
#
# At iterate   30    f=  3.08947D+00    |proj g|=  1.52033D-02
#
# At iterate   35    f=  3.08942D+00    |proj g|=  3.72236D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     35     42      1     0     0   3.722D-06   3.089D+00
#   F =   3.0894194709831875
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:304.584269214386
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.90121D+00    |proj g|=  9.10067D-02
#
# At iterate    5    f=  6.87978D+00    |proj g|=  2.25690D+00
#
# At iterate   10    f=  6.87270D+00    |proj g|=  4.79547D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     11     22      1     0     0   3.643D-03   6.873D+00
#   F =   6.8727025439444747
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:665.7794442186696
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.80557D+01    |proj g|=  7.86502D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#   ys=-4.443E+05  -gs= 1.353E-02 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# ...
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  3.09912D+00    |proj g|=  7.57367D-03
#
# At iterate   10    f=  3.07347D+00    |proj g|=  4.56418D-02
#
# At iterate   15    f=  3.06472D+00    |proj g|=  9.60128D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18     24      1     0     0   2.554D-07   3.065D+00
#   F =   3.0647193871032266
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:300.21306116190976
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.95997D+00    |proj g|=  3.34294D-02
#
# At iterate    5    f=  4.95798D+00    |proj g|=  2.40641D-02
#
# At iterate   10    f=  4.90324D+00    |proj g|=  1.99571D-01
#
# At iterate   15    f=  4.88896D+00    |proj g|=  2.69553D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     15     20      1     0     0   2.696D-06   4.889D+00
#   F =   4.8889621445680618
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:475.34036587853393
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.66854D+01    |proj g|=  2.01053D-03
#   ys=-7.939E+01  -gs= 6.138E-01 BFGS update SKIPPED
#
# At iterate    5    f=  1.40632D+01    |proj g|=  6.84999D+04
#   ys=-6.562E+01  -gs= 7.003E-01 BFGS update SKIPPED
#   ys=-3.439E-01  -gs= 5.365E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      7     90      2     3     0   1.124D+05   1.315D+01
#   F =   13.153489372311570
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1270.7349797419108
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.10197D+00    |proj g|=  1.68835D-02
#
# At iterate    5    f=  3.10136D+00    |proj g|=  1.04559D-02
#
# At iterate   10    f=  3.08543D+00    |proj g|=  1.26873D-01
#
# At iterate   15    f=  3.06903D+00    |proj g|=  1.52920D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     16     19      1     0     0   3.073D-06   3.069D+00
#   F =   3.0690321889014469
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:300.6270901345389
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.12416D+00    |proj g|=  1.59332D-01
#
# At iterate    5    f=  3.09966D+00    |proj g|=  1.44150D-02
#
# At iterate   10    f=  3.09925D+00    |proj g|=  2.70335D-03
#
# At iterate   15    f=  3.09397D+00    |proj g|=  5.42312D-02
#
# At iterate   20    f=  3.06825D+00    |proj g|=  1.66944D-02
#
# At iterate   25    f=  3.06621D+00    |proj g|=  1.00833D-02
#
# At iterate   30    f=  3.06590D+00    |proj g|=  1.37460D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33     39      1     0     0   6.108D-06   3.066D+00
#   F =   3.0659010338578643
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:302.32649925035497
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.74889D+00    |proj g|=  8.44414D-02
#
# At iterate    5    f=  6.71856D+00    |proj g|=  1.47337D-01
#
# At iterate   10    f=  6.71051D+00    |proj g|=  8.89744D-04
#
# At iterate   15    f=  6.70960D+00    |proj g|=  5.51610D-02
#
# At iterate   20    f=  6.69897D+00    |proj g|=  4.59311D-02
#
# At iterate   25    f=  6.69825D+00    |proj g|=  5.88889D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     25     33      1     0     0   5.889D-06   6.698D+00
#   F =   6.6982479373281612
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:649.0318019835034
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.62711D+01    |proj g|=  6.21298D-03
#   ys=-7.730E-11  -gs= 3.127E-10 BFGS update SKIPPED
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      5     92      2     1     0   2.531D+05   2.413D+01
#   F =   24.134216312670485
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:2324.8847660163665
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.77247D+00    |proj g|=  5.57251D-02
#
# At iterate    5    f=  4.74738D+00    |proj g|=  7.45904D-02
#
# At iterate   10    f=  4.74215D+00    |proj g|=  5.05521D-04
#
# At iterate   15    f=  4.74189D+00    |proj g|=  1.89004D-02
#
# At iterate   20    f=  4.73466D+00    |proj g|=  2.88448D-02
#
# At iterate   25    f=  4.73413D+00    |proj g|=  7.19567D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     25     33      1     0     0   7.196D-06   4.734D+00
#   F =   4.7341277995934012
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:460.47626876096655
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.98342D+00    |proj g|=  1.71628D-01
#   ys=-4.857E-03  -gs= 6.535E-03 BFGS update SKIPPED
#
# At iterate    5    f=  2.92491D+00    |proj g|=  2.97664D-02
#
# At iterate   10    f=  2.92293D+00    |proj g|=  1.02711D-03
#
# At iterate   15    f=  2.92057D+00    |proj g|=  3.20002D-02
#
# At iterate   20    f=  2.87973D+00    |proj g|=  3.06134D-02
#
# At iterate   25    f=  2.84939D+00    |proj g|=  4.57850D-02
#
# At iterate   30    f=  2.84778D+00    |proj g|=  1.98137D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     31     42      1     1     0   2.278D-06   2.848D+00
#   F =   2.8477843822284998
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:281.38730069393597
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.94554D+00    |proj g|=  4.47276D-02
#
# At iterate    5    f=  4.92820D+00    |proj g|=  4.33012D-03
#
# At iterate   10    f=  4.92756D+00    |proj g|=  2.13740D-02
#
# At iterate   15    f=  4.86782D+00    |proj g|=  3.01010D-01
#
# At iterate   20    f=  4.80756D+00    |proj g|=  3.28933D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     24     37      1     0     0   5.435D-07   4.808D+00
#   F =   4.8075524527716400
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:469.52503546607744
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.58906D+01    |proj g|=  5.99785D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#   ys=-3.081E+08  -gs= 5.539E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      2     31      2     1     0   2.961D+06   1.881D+00
#   F =   1.8814069450260484
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:190.61506672250064
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.09103D+00    |proj g|=  3.72719D-02
#
# At iterate    5    f=  3.08056D+00    |proj g|=  3.47745D-02
#
# At iterate   10    f=  3.07783D+00    |proj g|=  1.16848D-03
#   ys=-2.590E-04  -gs= 2.696E-04 BFGS update SKIPPED
#
# At iterate   15    f=  3.07434D+00    |proj g|=  9.55769D-04
#
# At iterate   20    f=  3.07399D+00    |proj g|=  2.28844D-02
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:297.7875439551824
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   25    f=  3.04247D+00    |proj g|=  2.03798D-01
#
# At iterate   30    f=  3.01863D+00    |proj g|=  1.46549D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33     58      1     1     0   8.745D-05   3.019D+00
#   F =   3.0186202495331500
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.98342D+00    |proj g|=  1.76988D-01
#
# At iterate    5    f=  2.94075D+00    |proj g|=  1.72204D-01
#
# At iterate   10    f=  2.92298D+00    |proj g|=  1.23344D-02
#
# At iterate   15    f=  2.92270D+00    |proj g|=  1.02674D-03
#
# At iterate   20    f=  2.92162D+00    |proj g|=  6.40712D-02
#
# At iterate   25    f=  2.86055D+00    |proj g|=  1.50505D-01
#
# At iterate   30    f=  2.84756D+00    |proj g|=  6.69660D-03
#
# At iterate   35    f=  2.84756D+00    |proj g|=  2.59797D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     36     48      1     0     0   5.226D-05   2.848D+00
#   F =   2.8475635566709609
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:283.36610144041225

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b>We are selecting those parameter which has minimum AIC score</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id='Fitting_the_ARIMA'></a>
# ## 5.2 Fitting the ARIMA model

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.98342D+00    |proj g|=  1.76988D-01
#
# At iterate    5    f=  2.94075D+00    |proj g|=  1.72204D-01
#
# At iterate   10    f=  2.92298D+00    |proj g|=  1.23344D-02
#
# At iterate   15    f=  2.92270D+00    |proj g|=  1.02674D-03
#
# At iterate   20    f=  2.92162D+00    |proj g|=  6.40712D-02
#
# At iterate   25    f=  2.86055D+00    |proj g|=  1.50505D-01
#
# At iterate   30    f=  2.84756D+00    |proj g|=  6.69660D-03
#
# At iterate   35    f=  2.84756D+00    |proj g|=  2.59797D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     36     48      1     0     0   5.226D-05   2.848D+00
#   F =   2.8475635566709609
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0949      0.313     -0.303      0.762      -0.708       0.518
# ma.L1         -1.0000      0.415     -2.409      0.016      -1.814      -0.186
# ar.S.L12      -0.0036      0.424     -0.008      0.993      -0.834       0.827
# ma.S.L12      -0.3011      0.501     -0.601      0.548      -1.283       0.681
# sigma2      2.476e+04   1.68e-05   1.48e+09      0.000    2.48e+04    2.48e+04
# ==============================================================================
#  This problem is unconstrained.

# %% [markdown]
# **Running model diagnostiscs to check any unusual behaviour**
# <br>1. If the model is correctly specified and the parameter estimates are reasonably close to the true values, then the residuals should have nearly the properties of white noise.
#
# <br>2. Plots can be used to better understand the distribution of errors beyond summary statistics. We would expect the forecast errors to be normally distributed around a zero mean.
#
# <br>3. The Q-Q plot can be used to quickly check the normality of the distribution of residual errors.
#
# <br>4. Finally, visualizing the autocorrelation for the residual errors. The x-axis shows the lag and the y-axis shows the correlation between an observation and the lag variable, where correlation values are between -1 and 1 for negative and positive correlations respectively. We would not expect there to be any correlation between the residuals. This would be shown by autocorrelation scores being below the threshold of significance (dashed and dotted horizontal lines on the plot).

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 results.plot_diagnostics(figsize=(16, 8))
#       2 plt.show()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/datascience/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py:4613, in MLEResults.plot_diagnostics(self, variable, lags, fig, figsize, truncate_endog_names, auto_ylims, bartlett_confint, acf_kwargs)
#    4608 resid = pd.Series(
#    4609     self.filter_results.standardized_forecasts_error[variable, d:],
#    4610     index=ix)
#    4612 if resid.shape[0] < max(d, lags):
# -> 4613     raise ValueError(
#    4614         "Length of endogenous variable must be larger the the number "
#    4615         "of lags used in the model and the number of observations "
#    4616         "burned in the log-likelihood calculation."
#    4617     )
#    4619 # Top-left: residuals vs time
#    4620 ax = fig.add_subplot(221)
#
# ValueError: Length of endogenous variable must be larger the the number of lags used in the model and the number of observations burned in the log-likelihood calculation.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b>The model diagnostics indicates that the model residuals are near normally distributed</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id='Validating_Forecasts'></a>
# ## 5.3 Validating Forecasts

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="key.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b>We compare predicted sales to real sales of the time series to understand the accuracy of our forecasts</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
#set forecasts to start at 2017–01–01 to the end of the data to forecast
pred = results.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
plt.legend()
plt.show()

# %% [markdown]
# The above plot indicates the observed value and the rolling forecast predications (A rolling forecast is an add/drop process for predicting the future over a set period of time). The predicated values align well with the true values.

# %% [markdown]
# <a id="Calculating_MSE_and_RMSE"> </a>
# ## 5.4 Calculating MSE and RMSE

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2017-01-01':]
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))

print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="note.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                     <b>MSE measures the average of the squares of the errors of an estimator i.e. the average squared difference between the estimated values and what is estimated. RMSE tells us that our model was able to forecast the average daily furniture sales in the test set within 160.34 of the real sales..</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id="Visualizing_the_Forecast"> </a>
# ## 5.5 Visualizing the Forecast

# %%
pred_uc = results.get_forecast(steps=13)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
print(pred_ci)
plt.legend()
plt.show()

# %% [markdown]
# <a id="Conclusion"> </a>
# # Conclusion

# %% [markdown]
# We observe that sales of furniture produces seasonal pattern. Early of the year is the off season for furniture sales in the superstore. The sales for furniture increases linearly over time.
